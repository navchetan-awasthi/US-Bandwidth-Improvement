# %%
#import the neccesary libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from PIL import Image
import numpy as np
import skimage
import skimage.transform
import os
import tensorflow.keras.backend as K
from skimage.metrics import structural_similarity as ssim
import math
from tensorflow.keras.applications.vgg16 import VGG16
from sobel_edge import sobel 

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
#create the training set 
import skimage.transform
def CreateSet(input_list,N_patches,patchsize):
    """
    Creates an array that can be used as input and output for the model
    parameters: input_list, a list with indices of the images that are used
                N_patches, the amount of image patches the model creates per image
                patchszize, the width and height of the square image patch
    
    """
    X = np.zeros((len(input_list)*N_patches, patchsize, patchsize, 1), dtype=np.float32)
    y = np.zeros((len(input_list)*N_patches, patchsize, patchsize, 3), dtype=np.float32)
    for j in range(N_patches):
        for n,i in enumerate(input_list):
            #random pixel location
            ii = j*len(input_list)+n
            xloc = random.randint(0,401-patchsize)
            yloc = random.randint(0,801-patchsize)
            #input 
            img_input = Image.open('bandLimited/input_%03d.png' % (i+1))
            in_img_input = tf.keras.preprocessing.image.img_to_array(img_input)
            in_img_input = in_img_input[yloc:yloc+patchsize,xloc:xloc+patchsize]
            in_img_input = skimage.transform.resize(in_img_input , (patchsize , patchsize , 1) , mode = 'constant' , preserve_range = True)
            X[ii] = in_img_input / 255.0
            #output
            img_output = Image.open('groundTruth/target_%03d.png' % (i+1))
            in_img_output = tf.keras.preprocessing.image.img_to_array(img_output)
            in_img_output = in_img_output[yloc:yloc+patchsize,xloc:xloc+patchsize]
            in_img_output = skimage.transform.resize(in_img_output , (patchsize , patchsize , 1) , mode = 'constant' , preserve_range = True)
            in_img_output = np.concatenate((in_img_output,in_img_output,in_img_output),axis=-1)
            y[ii] = in_img_output / 255.0
            if ii % 1000 == 0:
                print(ii)
    print('Done')
    return X,y
#amount of patches per image
N_patches = 64
#width and height of the patches
patchsize = 128
#Train set is image 1 till 401
X_train,y_train = CreateSet(range(401),N_patches,patchsize)
#validation set is image 402 till 535
X_valid,y_valid = CreateSet(range(401,535),N_patches,patchsize)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# Done
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# Done

# %%
#Create the arrays for the Test set which are the image 535 till 669
test_set_indices = range(535,669)
Test_set_X = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
Test_set_y = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
for i,n in enumerate(test_set_indices):
    img = Image.open('bandLimited/input_%03d.png' % (n+1))
    in_img_input = tf.keras.preprocessing.image.img_to_array(img)
    in_img_input = skimage.transform.resize(in_img_input , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
    Test_set_X[i] =in_img_input / 255.0

    img = Image.open('groundTruth/target_%03d.png' % (n+1))
    in_img_output = tf.keras.preprocessing.image.img_to_array(img)
    in_img_output = skimage.transform.resize(in_img_output , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
    Test_set_y[i] =in_img_output / 255.0

# %%
def Sobel(x):
    dims = tf.shape (x)#return tf.squeeze( tf.image.sobel_edges(x))
    return tf.reshape(sobel(x),[dims[0],dims[1],dims[2],4])

def Sobel_shape(input_shape):
    dims = [input_shape[0],input_shape[1] ,input_shape[2],4]
    output_shape = tuple(dims)
    return output_shape

def RED_Net(img_tensor , n_filters = 64):
    """
    Creates the RED_net model
    returns: RED_net, the RED_net model
    """
# #     #block1 (connection 1-->2)
    shortcut1 = img_tensor
    
    #layer 1: edge detection layer which uses four kernel filters-
    x = tf.keras.layers.Lambda(Sobel, output_shape =  Sobel_shape, name='sobel-edge')(img_tensor)    #block1 (connection 1-->2)
    
    x = tf.keras.layers.concatenate([x, shortcut1])
    
#     #block 2(connection 2-->9)
    shortcut2 = x
#     #layer 2
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (5 , 5), padding = 'same')(x)
    
    #block 3(connection 3-->8)
    shortcut3 = x
    #layer 3
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=2, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
#     #block 4 (connection 4-->7)
    shortcut4 = x
    #layer 4
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
    #layer 5
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=4, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
    #layer 6
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
#     #block 4 (connection 4-->7)
    x = tf.keras.layers.concatenate([x, shortcut4])

    #layer 7
    x = tf.keras.layers.Conv2D(filters = n_filters ,kernel_size = (3 , 3),dilation_rate=2,padding = 'same')(x) 
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    #block 3(connection 3-->8)    
    x = tf.keras.layers.concatenate([x, shortcut3])

    #layer 8
    x = tf.keras.layers.Conv2D(1 , (3 , 3), padding = 'same')(x)
    #block 2(connection 2-->9)
    x = tf.keras.layers.concatenate([x, shortcut2])

    #layer 9 
    output = tf.keras.layers.Conv2D(3 , (3 , 3) , padding = 'same')(x)

    RED_net = tf.keras.Model(inputs = [img_tensor] , outputs = [output])

    return RED_net

# %%
def CustomMSE(y_predict,y_true):
    factor = 1e3
    mse = factor*K.mean(K.square(y_predict-y_true))
    return mse

# %%
image_shape = (None,None, 3)
vgg = VGG16(include_top=False, weights='imagenet', input_shape=image_shape)
selectedLayers = ['block1_conv2','block2_conv2','block3_conv3','block4_conv3']
selectedOutputs = [vgg.get_layer(i).output for i in selectedLayers]
loss_model = tf.keras.Model(inputs=vgg.input, outputs=selectedOutputs)
loss_model.trainable = False
def perceptual_loss(y_true, y_pred):
    mse = 0
    for i in range(0,3):
        mse = (mse+ K.mean(K.square(loss_model(y_true)[i] - loss_model(y_pred)[i])))
    return mse

loss = [perceptual_loss, tf.keras.losses.MeanSquaredError]
loss_weights = [70,30]

# %%
#define and compile the model
img_tensor = tf.keras.layers.Input((None , None , 1) , name = 'img_tensor')
model = RED_Net(img_tensor,64)
model.compile(optimizer = tf.keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.999, epsilon=1e-08, decay=0.0),
            loss = loss,
            loss_weights = loss_weights,
            metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model_path = 'model_RED_net_perceptual_loss_ultrasound.h5'
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.0001, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(model_path, verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
#load the model
model.load_weights(model_path)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_tensor (InputLayer)         [(None, None, None,  0
# __________________________________________________________________________________________________
# sobel-edge (Lambda)             (None, None, None, 4 0           img_tensor[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 5 0           sobel-edge[0][0]
#                                                                  img_tensor[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 8064        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 6 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 6 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 6 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 1 0           activation_3[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 6 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 1 0           activation_4[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 1153        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 6 0           conv2d_6[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 3 165         concatenate_3[0][0]
# ==================================================================================================
# Total params: 232,166
# Trainable params: 231,526
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
#train the model
results = model.fit(X_train,y_train,epochs=100, callbacks=callbacks,batch_size = 16,
                    validation_data=(X_valid,y_valid),shuffle=False)
# Out:
# Epoch 1/100
# 1604/1604 [==============================] - ETA: 0s - loss: 3034.3093 - root_mean_squared_error: 0.3916
# Epoch 00001: val_loss improved from inf to 2254.19092, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 3034.3093 - root_mean_squared_error: 0.3916 - val_loss: 2254.1909 - val_root_mean_squared_error: 0.2318 - lr: 1.0000e-04
# Epoch 2/100
# 1604/1604 [==============================] - ETA: 0s - loss: 2137.6343 - root_mean_squared_error: 0.1923
# Epoch 00002: val_loss improved from 2254.19092 to 2067.06909, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 2137.6343 - root_mean_squared_error: 0.1923 - val_loss: 2067.0691 - val_root_mean_squared_error: 0.1593 - lr: 1.0000e-04
# Epoch 3/100
# 1604/1604 [==============================] - ETA: 0s - loss: 2013.5151 - root_mean_squared_error: 0.1489
# Epoch 00003: val_loss improved from 2067.06909 to 1985.94263, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 2013.5151 - root_mean_squared_error: 0.1489 - val_loss: 1985.9426 - val_root_mean_squared_error: 0.1379 - lr: 1.0000e-04
# Epoch 4/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1954.3374 - root_mean_squared_error: 0.1359
# Epoch 00004: val_loss improved from 1985.94263 to 1948.60071, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1954.3374 - root_mean_squared_error: 0.1359 - val_loss: 1948.6007 - val_root_mean_squared_error: 0.1308 - lr: 1.0000e-04
# Epoch 5/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1924.4506 - root_mean_squared_error: 0.1308
# Epoch 00005: val_loss improved from 1948.60071 to 1927.20593, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 229s 143ms/step - loss: 1924.4506 - root_mean_squared_error: 0.1308 - val_loss: 1927.2059 - val_root_mean_squared_error: 0.1272 - lr: 1.0000e-04
# Epoch 6/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1906.0317 - root_mean_squared_error: 0.1281
# Epoch 00006: val_loss improved from 1927.20593 to 1915.67273, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 229s 143ms/step - loss: 1906.0317 - root_mean_squared_error: 0.1281 - val_loss: 1915.6727 - val_root_mean_squared_error: 0.1253 - lr: 1.0000e-04
# Epoch 7/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1893.2803 - root_mean_squared_error: 0.1265
# Epoch 00007: val_loss improved from 1915.67273 to 1906.90686, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1893.2803 - root_mean_squared_error: 0.1265 - val_loss: 1906.9069 - val_root_mean_squared_error: 0.1243 - lr: 1.0000e-04
# Epoch 8/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1883.9078 - root_mean_squared_error: 0.1253
# Epoch 00008: val_loss improved from 1906.90686 to 1900.78455, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1883.9078 - root_mean_squared_error: 0.1253 - val_loss: 1900.7845 - val_root_mean_squared_error: 0.1236 - lr: 1.0000e-04
# Epoch 9/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1876.5062 - root_mean_squared_error: 0.1244
# Epoch 00009: val_loss improved from 1900.78455 to 1895.38123, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1876.5062 - root_mean_squared_error: 0.1244 - val_loss: 1895.3812 - val_root_mean_squared_error: 0.1226 - lr: 1.0000e-04
# Epoch 10/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1870.4113 - root_mean_squared_error: 0.1235
# Epoch 00010: val_loss improved from 1895.38123 to 1890.27625, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1870.4113 - root_mean_squared_error: 0.1235 - val_loss: 1890.2762 - val_root_mean_squared_error: 0.1220 - lr: 1.0000e-04
# Epoch 11/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1865.3260 - root_mean_squared_error: 0.1228
# Epoch 00011: val_loss improved from 1890.27625 to 1886.09070, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1865.3260 - root_mean_squared_error: 0.1228 - val_loss: 1886.0907 - val_root_mean_squared_error: 0.1212 - lr: 1.0000e-04
# Epoch 12/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1860.8813 - root_mean_squared_error: 0.1222
# Epoch 00012: val_loss improved from 1886.09070 to 1883.31689, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1860.8813 - root_mean_squared_error: 0.1222 - val_loss: 1883.3169 - val_root_mean_squared_error: 0.1205 - lr: 1.0000e-04
# Epoch 13/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1857.0345 - root_mean_squared_error: 0.1216
# Epoch 00013: val_loss improved from 1883.31689 to 1880.65918, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1857.0345 - root_mean_squared_error: 0.1216 - val_loss: 1880.6592 - val_root_mean_squared_error: 0.1200 - lr: 1.0000e-04
# Epoch 14/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1853.6145 - root_mean_squared_error: 0.1211
# Epoch 00014: val_loss improved from 1880.65918 to 1877.58472, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1853.6145 - root_mean_squared_error: 0.1211 - val_loss: 1877.5847 - val_root_mean_squared_error: 0.1197 - lr: 1.0000e-04
# Epoch 15/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1850.5784 - root_mean_squared_error: 0.1206
# Epoch 00015: val_loss improved from 1877.58472 to 1875.62512, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1850.5784 - root_mean_squared_error: 0.1206 - val_loss: 1875.6251 - val_root_mean_squared_error: 0.1194 - lr: 1.0000e-04
# Epoch 16/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1847.7765 - root_mean_squared_error: 0.1202
# Epoch 00016: val_loss improved from 1875.62512 to 1874.02039, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1847.7765 - root_mean_squared_error: 0.1202 - val_loss: 1874.0204 - val_root_mean_squared_error: 0.1191 - lr: 1.0000e-04
# Epoch 17/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1845.3334 - root_mean_squared_error: 0.1198
# Epoch 00017: val_loss improved from 1874.02039 to 1871.37061, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1845.3334 - root_mean_squared_error: 0.1198 - val_loss: 1871.3706 - val_root_mean_squared_error: 0.1188 - lr: 1.0000e-04
# Epoch 18/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1842.9713 - root_mean_squared_error: 0.1195
# Epoch 00018: val_loss improved from 1871.37061 to 1870.30078, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1842.9713 - root_mean_squared_error: 0.1195 - val_loss: 1870.3008 - val_root_mean_squared_error: 0.1184 - lr: 1.0000e-04
# Epoch 19/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1840.8384 - root_mean_squared_error: 0.1192
# Epoch 00019: val_loss improved from 1870.30078 to 1868.89587, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1840.8384 - root_mean_squared_error: 0.1192 - val_loss: 1868.8959 - val_root_mean_squared_error: 0.1182 - lr: 1.0000e-04
# Epoch 20/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1838.8407 - root_mean_squared_error: 0.1190
# Epoch 00020: val_loss improved from 1868.89587 to 1867.09094, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1838.8407 - root_mean_squared_error: 0.1190 - val_loss: 1867.0909 - val_root_mean_squared_error: 0.1179 - lr: 1.0000e-04
# Epoch 21/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1836.8850 - root_mean_squared_error: 0.1187
# Epoch 00021: val_loss improved from 1867.09094 to 1866.62549, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1836.8850 - root_mean_squared_error: 0.1187 - val_loss: 1866.6255 - val_root_mean_squared_error: 0.1179 - lr: 1.0000e-04
# Epoch 22/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1835.0798 - root_mean_squared_error: 0.1185
# Epoch 00022: val_loss improved from 1866.62549 to 1864.85571, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1835.0798 - root_mean_squared_error: 0.1185 - val_loss: 1864.8557 - val_root_mean_squared_error: 0.1175 - lr: 1.0000e-04
# Epoch 23/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1833.3604 - root_mean_squared_error: 0.1183
# Epoch 00023: val_loss improved from 1864.85571 to 1864.14221, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1833.3604 - root_mean_squared_error: 0.1183 - val_loss: 1864.1422 - val_root_mean_squared_error: 0.1175 - lr: 1.0000e-04
# Epoch 24/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1831.7388 - root_mean_squared_error: 0.1181
# Epoch 00024: val_loss improved from 1864.14221 to 1862.99243, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1831.7388 - root_mean_squared_error: 0.1181 - val_loss: 1862.9924 - val_root_mean_squared_error: 0.1169 - lr: 1.0000e-04
# Epoch 25/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1830.2552 - root_mean_squared_error: 0.1179
# Epoch 00025: val_loss improved from 1862.99243 to 1861.89343, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1830.2552 - root_mean_squared_error: 0.1179 - val_loss: 1861.8934 - val_root_mean_squared_error: 0.1170 - lr: 1.0000e-04
# Epoch 26/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1828.8295 - root_mean_squared_error: 0.1177
# Epoch 00026: val_loss improved from 1861.89343 to 1860.82935, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1828.8295 - root_mean_squared_error: 0.1177 - val_loss: 1860.8293 - val_root_mean_squared_error: 0.1168 - lr: 1.0000e-04
# Epoch 27/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1827.5227 - root_mean_squared_error: 0.1175
# Epoch 00027: val_loss improved from 1860.82935 to 1860.27014, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1827.5227 - root_mean_squared_error: 0.1175 - val_loss: 1860.2701 - val_root_mean_squared_error: 0.1168 - lr: 1.0000e-04
# Epoch 28/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1826.2482 - root_mean_squared_error: 0.1173
# Epoch 00028: val_loss improved from 1860.27014 to 1860.08618, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1826.2482 - root_mean_squared_error: 0.1173 - val_loss: 1860.0862 - val_root_mean_squared_error: 0.1166 - lr: 1.0000e-04
# Epoch 29/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1825.1053 - root_mean_squared_error: 0.1172
# Epoch 00029: val_loss improved from 1860.08618 to 1859.25842, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1825.1053 - root_mean_squared_error: 0.1172 - val_loss: 1859.2584 - val_root_mean_squared_error: 0.1165 - lr: 1.0000e-04
# Epoch 30/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1823.9335 - root_mean_squared_error: 0.1170
# Epoch 00030: val_loss improved from 1859.25842 to 1857.94922, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1823.9335 - root_mean_squared_error: 0.1170 - val_loss: 1857.9492 - val_root_mean_squared_error: 0.1163 - lr: 1.0000e-04
# Epoch 31/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1822.9917 - root_mean_squared_error: 0.1169
# Epoch 00031: val_loss improved from 1857.94922 to 1857.53955, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 142ms/step - loss: 1822.9917 - root_mean_squared_error: 0.1169 - val_loss: 1857.5396 - val_root_mean_squared_error: 0.1164 - lr: 1.0000e-04
# Epoch 32/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1821.8947 - root_mean_squared_error: 0.1167
# Epoch 00032: val_loss improved from 1857.53955 to 1856.99597, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1821.8947 - root_mean_squared_error: 0.1167 - val_loss: 1856.9960 - val_root_mean_squared_error: 0.1160 - lr: 1.0000e-04
# Epoch 33/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1820.9224 - root_mean_squared_error: 0.1166
# Epoch 00033: val_loss improved from 1856.99597 to 1855.94397, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1820.9224 - root_mean_squared_error: 0.1166 - val_loss: 1855.9440 - val_root_mean_squared_error: 0.1158 - lr: 1.0000e-04
# Epoch 34/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1820.0378 - root_mean_squared_error: 0.1164
# Epoch 00034: val_loss did not improve from 1855.94397
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1820.0378 - root_mean_squared_error: 0.1164 - val_loss: 1856.6891 - val_root_mean_squared_error: 0.1160 - lr: 1.0000e-04
# Epoch 35/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1819.1006 - root_mean_squared_error: 0.1163
# Epoch 00035: val_loss did not improve from 1855.94397
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1819.1006 - root_mean_squared_error: 0.1163 - val_loss: 1855.9618 - val_root_mean_squared_error: 0.1158 - lr: 1.0000e-04
# Epoch 36/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1818.3251 - root_mean_squared_error: 0.1162
# Epoch 00036: val_loss improved from 1855.94397 to 1855.14343, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1818.3251 - root_mean_squared_error: 0.1162 - val_loss: 1855.1434 - val_root_mean_squared_error: 0.1155 - lr: 1.0000e-04
# Epoch 37/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1817.4531 - root_mean_squared_error: 0.1160
# Epoch 00037: val_loss improved from 1855.14343 to 1855.03479, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1817.4531 - root_mean_squared_error: 0.1160 - val_loss: 1855.0348 - val_root_mean_squared_error: 0.1156 - lr: 1.0000e-04
# Epoch 38/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1816.7096 - root_mean_squared_error: 0.1159
# Epoch 00038: val_loss improved from 1855.03479 to 1853.90039, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1816.7096 - root_mean_squared_error: 0.1159 - val_loss: 1853.9004 - val_root_mean_squared_error: 0.1156 - lr: 1.0000e-04
# Epoch 39/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1816.0181 - root_mean_squared_error: 0.1157
# Epoch 00039: val_loss improved from 1853.90039 to 1853.33118, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1816.0181 - root_mean_squared_error: 0.1157 - val_loss: 1853.3312 - val_root_mean_squared_error: 0.1154 - lr: 1.0000e-04
# Epoch 40/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1815.2307 - root_mean_squared_error: 0.1156
# Epoch 00040: val_loss did not improve from 1853.33118
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1815.2307 - root_mean_squared_error: 0.1156 - val_loss: 1853.8702 - val_root_mean_squared_error: 0.1154 - lr: 1.0000e-04
# Epoch 41/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1814.5565 - root_mean_squared_error: 0.1155
# Epoch 00041: val_loss did not improve from 1853.33118
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1814.5565 - root_mean_squared_error: 0.1155 - val_loss: 1853.6957 - val_root_mean_squared_error: 0.1153 - lr: 1.0000e-04
# Epoch 42/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1813.9087 - root_mean_squared_error: 0.1154
# Epoch 00042: val_loss improved from 1853.33118 to 1852.53882, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1813.9087 - root_mean_squared_error: 0.1154 - val_loss: 1852.5388 - val_root_mean_squared_error: 0.1151 - lr: 1.0000e-04
# Epoch 43/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1813.2645 - root_mean_squared_error: 0.1153
# Epoch 00043: val_loss did not improve from 1852.53882
# 1604/1604 [==============================] - 225s 140ms/step - loss: 1813.2645 - root_mean_squared_error: 0.1153 - val_loss: 1852.5425 - val_root_mean_squared_error: 0.1151 - lr: 1.0000e-04
# Epoch 44/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1812.6465 - root_mean_squared_error: 0.1152
# Epoch 00044: val_loss improved from 1852.53882 to 1852.24878, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1812.6465 - root_mean_squared_error: 0.1152 - val_loss: 1852.2488 - val_root_mean_squared_error: 0.1149 - lr: 1.0000e-04
# Epoch 45/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1812.0063 - root_mean_squared_error: 0.1150
# Epoch 00045: val_loss improved from 1852.24878 to 1852.23572, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 227s 141ms/step - loss: 1812.0063 - root_mean_squared_error: 0.1150 - val_loss: 1852.2357 - val_root_mean_squared_error: 0.1149 - lr: 1.0000e-04
# Epoch 46/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1811.4794 - root_mean_squared_error: 0.1149
# Epoch 00046: val_loss improved from 1852.23572 to 1851.79480, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1811.4794 - root_mean_squared_error: 0.1149 - val_loss: 1851.7948 - val_root_mean_squared_error: 0.1146 - lr: 1.0000e-04
# Epoch 47/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1810.8608 - root_mean_squared_error: 0.1148
# Epoch 00047: val_loss improved from 1851.79480 to 1851.40857, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 228s 142ms/step - loss: 1810.8608 - root_mean_squared_error: 0.1148 - val_loss: 1851.4086 - val_root_mean_squared_error: 0.1147 - lr: 1.0000e-04
# Epoch 48/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1810.3346 - root_mean_squared_error: 0.1147
# Epoch 00048: val_loss improved from 1851.40857 to 1851.05432, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1810.3346 - root_mean_squared_error: 0.1147 - val_loss: 1851.0543 - val_root_mean_squared_error: 0.1144 - lr: 1.0000e-04
# Epoch 49/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1809.7781 - root_mean_squared_error: 0.1146
# Epoch 00049: val_loss improved from 1851.05432 to 1850.94922, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1809.7781 - root_mean_squared_error: 0.1146 - val_loss: 1850.9492 - val_root_mean_squared_error: 0.1144 - lr: 1.0000e-04
# Epoch 50/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1809.3253 - root_mean_squared_error: 0.1145
# Epoch 00050: val_loss improved from 1850.94922 to 1850.38904, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1809.3253 - root_mean_squared_error: 0.1145 - val_loss: 1850.3890 - val_root_mean_squared_error: 0.1143 - lr: 1.0000e-04
# Epoch 51/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1808.8221 - root_mean_squared_error: 0.1144
# Epoch 00051: val_loss did not improve from 1850.38904
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1808.8221 - root_mean_squared_error: 0.1144 - val_loss: 1850.5079 - val_root_mean_squared_error: 0.1144 - lr: 1.0000e-04
# Epoch 52/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1808.3076 - root_mean_squared_error: 0.1144
# Epoch 00052: val_loss improved from 1850.38904 to 1849.57788, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1808.3076 - root_mean_squared_error: 0.1144 - val_loss: 1849.5779 - val_root_mean_squared_error: 0.1142 - lr: 1.0000e-04
# Epoch 53/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1807.8673 - root_mean_squared_error: 0.1143
# Epoch 00053: val_loss did not improve from 1849.57788
# 1604/1604 [==============================] - 225s 140ms/step - loss: 1807.8673 - root_mean_squared_error: 0.1143 - val_loss: 1850.4673 - val_root_mean_squared_error: 0.1143 - lr: 1.0000e-04
# Epoch 54/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1807.3700 - root_mean_squared_error: 0.1142
# Epoch 00054: val_loss improved from 1849.57788 to 1849.18652, saving model to model_RED_net_perceptual_loss_ultrasound.h5
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1807.3700 - root_mean_squared_error: 0.1142 - val_loss: 1849.1865 - val_root_mean_squared_error: 0.1141 - lr: 1.0000e-04
# Epoch 55/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1806.9574 - root_mean_squared_error: 0.1141
# Epoch 00055: val_loss did not improve from 1849.18652
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1806.9574 - root_mean_squared_error: 0.1141 - val_loss: 1849.2478 - val_root_mean_squared_error: 0.1141 - lr: 1.0000e-04
# Epoch 56/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1806.5691 - root_mean_squared_error: 0.1141
# Epoch 00056: val_loss did not improve from 1849.18652
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1806.5691 - root_mean_squared_error: 0.1141 - val_loss: 1849.2386 - val_root_mean_squared_error: 0.1141 - lr: 1.0000e-04
# Epoch 57/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1806.1346 - root_mean_squared_error: 0.1140
# Epoch 00057: val_loss did not improve from 1849.18652
# 1604/1604 [==============================] - 224s 140ms/step - loss: 1806.1346 - root_mean_squared_error: 0.1140 - val_loss: 1850.2670 - val_root_mean_squared_error: 0.1139 - lr: 1.0000e-04
# Epoch 58/100
# 1604/1604 [==============================] - ETA: 0s - loss: 1805.6956 - root_mean_squared_error: 0.1139
# Epoch 00058: val_loss did not improve from 1849.18652
# 1604/1604 [==============================] - 226s 141ms/step - loss: 1805.6956 - root_mean_squared_error: 0.1139 - val_loss: 1849.7072 - val_root_mean_squared_error: 0.1138 - lr: 1.0000e-04
# Epoch 59/100
#   24/1604 [..............................] - ETA: 3:04 - loss: 1802.7394 - root_mean_squared_error: 0.1141
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-897ee7b5b17e> in <module>
#       1 #train the model
# ----> 2 results = model.fit(X_train,y_train,epochs=100, callbacks=callbacks,batch_size = 16,
#       3                     validation_data=(X_valid,y_valid),shuffle=False)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     853                 context.async_wait()
#     854               logs = tmp_logs  # No error, now safe to assign to logs.
# --> 855               callbacks.on_train_batch_end(step, logs)
#     856         epoch_logs = copy.copy(logs)
#     857
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     387     """
#     388     if self._should_call_train_batch_hooks:
# --> 389       logs = self._process_logs(logs)
#     390       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     391
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _process_logs(self, logs)
#     263     """Turns tensors into numpy arrays or Python scalars."""
#     264     if logs:
# --> 265       return tf_utils.to_numpy_or_python_type(logs)
#     266     return {}
#     267
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#     522
# --> 523   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     524
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     517   def _to_single_numpy_or_python_type(t):
#     518     if isinstance(t, ops.Tensor):
# --> 519       x = t.numpy()
#     520       return x.item() if np.ndim(x) == 0 else x
#     521     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in numpy(self)
#     959     """
#     960     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 961     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     962     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     963
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     925     # pylint: disable=protected-access
#     926     try:
# --> 927       return self._numpy_internal()
#     928     except core._NotOkStatusException as e:
#     929       six.raise_from(core._status_to_exception(e.code, e.message), None)
#
# KeyboardInterrupt:

# %%
#visualise the accuracy and losses of the model
# list all data in history
print(results.history.keys())
# summarize history for accuracy
plt.plot(results.history['root_mean_squared_error'])
plt.plot(results.history['val_root_mean_squared_error'])
plt.title('model root_mean_squared_error')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error', 'lr'])

# %%
n =66
prediction = model.predict(np.expand_dims(Test_set_X[n] , 0))

prediction_image = prediction.squeeze()

fig,ax = plt.subplots(1,3, figsize=(12,6))
ax[0].imshow(Test_set_X[n].squeeze(),cmap = 'gray')
ax[1].imshow(prediction_image[:,:,0],cmap='gray')
ax[2].imshow(Test_set_y[n].squeeze(),cmap='gray')
plt.show()

# %%
Train_set_indices = range(535)
Train_set_X = np.zeros((len(Train_set_indices), 801, 401,1), dtype=np.float32)
for i in Train_set_indices:
    img = Image.open('bandLimited/input_%03d.png' % (i+1))
    in_img_input = tf.keras.preprocessing.image.img_to_array(img)
    in_img_input = skimage.transform.resize(in_img_input , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
    Train_set_X[i] =in_img_input / 255.0

# %%
prediction_images = np.zeros((len(Train_set_X),801,401),dtype=np.float32)
for i in Train_set_indices:
    prediction_image = model.predict(np.expand_dims(Train_set_X[i] , 0))
    prediction_image = prediction_image[:,:,:,0]
    prediction_image = prediction_image.squeeze()*255.0
    prediction_image  = Image.fromarray(prediction_image)
    if prediction_image.mode == "F":
        prediction_image = prediction_image.convert('RGB')
    prediction_image.save('bandLimited_model1/input_%03d.png' % (i+1))

# %%
#Create the arrays for the Test set which are the image 535 till 669
def CreateTestSet(test_set_indices,input_dir_test,output_dir_test):
    """
    Function that reads in the test sets images as arrays and scales them between 0 and 1
    parameters:test_set_indices: The indices of the the images in the test set
                 input_dir_test: The directory where the input png images are stored
                output_dir_test: The directory where the output png images are stored
    returns: Test_set_X: an array of input images
             Test_set_y: an array of output images
    """
    Test_set_X = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
    Test_set_y = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
    for i,n in enumerate(test_set_indices):
        img = Image.open(input_dir_test+'/input_%03d.png' % (n+1))
        in_img_input = tf.keras.preprocessing.image.img_to_array(img)
        in_img_input = skimage.transform.resize(in_img_input , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
        Test_set_X[i] =in_img_input / 255.0

        img = Image.open(output_dir_test+'/target_%03d.png' % (n+1))
        in_img_output = tf.keras.preprocessing.image.img_to_array(img)
        in_img_output = skimage.transform.resize(in_img_output , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
        Test_set_y[i] =in_img_output / 255.0    
    print('Done')
    return Test_set_X, Test_set_y
#Run for all datasets
for dataset in ['','CIRS_','carotid_']:
    if dataset == '':
        test_set_indices = range(535,669)
        input_dir_test = 'bandLimited'
        output_dir_test = 'groundTruth'
    if dataset == 'CIRS_':
        test_set_indices = range(11)
        input_dir_test = 'CIRSBandLimited'
        output_dir_test = 'CIRSGroundTruth'
    if dataset =='carotid_':
        test_set_indices = range(70)
        input_dir_test = 'carotidBandLimited'
        output_dir_test = 'carotidGroundTruth'
    #Define the input and output for the test set
    Test_set_X, Test_set_y = CreateTestSet(test_set_indices,input_dir_test,output_dir_test)
    prediction_images = np.zeros((len(Test_set_X),801,401),dtype=np.float32)
    #Create an array with all prediction images
    for i in range(len(Test_set_X)):
        prediction_image = model.predict(np.expand_dims(Test_set_X[i] , 0))
        prediction_image = prediction_image[:,:,:,0]
        prediction_images[i] = prediction_image.squeeze()
    #save the prediction images as an npy file
    np.save('Model_output_test_'+dataset+'model1_ultrasound.npy',prediction_images)
# Out:
# Done
# Done
# Done
