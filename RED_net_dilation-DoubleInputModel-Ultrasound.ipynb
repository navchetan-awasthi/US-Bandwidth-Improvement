# %%
#import the neccesary libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from PIL import Image
import numpy as np
import skimage
import skimage.transform
import os
import tensorflow.keras.backend as K
from skimage.metrics import structural_similarity as ssim
import math
from tensorflow.keras.applications.vgg16 import VGG16
from sobel_edge import sobel 

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import skimage.transform

input_path = os.listdir('bandLimited')
#amount of patches per image
N_patches = 32
#width and height of the patches
patchsize = 128
def CreateSet(input_list,N_patches,patchsize):
    """
    Creates an array that can be used as input and output for the model
    parameters: input_list, a list with indices of the images that are used
                N_patches, the amount of image patches the model creates per image
                patchszize, the width and height of the square image patch
    
    """
    X = np.zeros((len(input_list)*N_patches, patchsize, patchsize, 2), dtype=np.float32)
    y = np.zeros((len(input_list)*N_patches, patchsize, patchsize, 1), dtype=np.float32)
    for j in range(N_patches):
        for n,i in enumerate(input_list):
            #random pixel location
            ii = j*len(input_list)+n
            xloc = random.randint(0,401-patchsize)
            yloc = random.randint(0,801-patchsize)
            #input 
            img_input1 = Image.open('bandLimited_model1/input_%03d.png' % (i+1))
            in_img_input1 = tf.keras.preprocessing.image.img_to_array(img_input1)
            in_img_input1 = in_img_input1[yloc:yloc+patchsize,xloc:xloc+patchsize]
            in_img_input1 = skimage.transform.resize(in_img_input1 , (patchsize , patchsize , 1) , mode = 'constant' , preserve_range = True)
            img_input2 = Image.open('bandLimited_model2/input_%03d.png' % (i+1))
            in_img_input2 = tf.keras.preprocessing.image.img_to_array(img_input2)
            in_img_input2 = in_img_input2[yloc:yloc+patchsize,xloc:xloc+patchsize]
            in_img_input2 = skimage.transform.resize(in_img_input2 , (patchsize , patchsize , 1) , mode = 'constant' , preserve_range = True)
            X1 = in_img_input1 / 255.0
            X2 = in_img_input2 / 255.0
            X[ii] = np.concatenate((X1,X2),axis=-1)
            #output
            img_output = Image.open('groundTruth/target_%03d.png' % (i+1))
            in_img_output = tf.keras.preprocessing.image.img_to_array(img_output)
            in_img_output = in_img_output[yloc:yloc+patchsize,xloc:xloc+patchsize]
            in_img_output = skimage.transform.resize(in_img_output , (patchsize , patchsize , 1) , mode = 'constant' , preserve_range = True)
            y[ii] = in_img_output / 255.0
            if ii % 1000 == 0:
                print(ii)
    print('Done')
    return X,y
#amount of patches per image
N_patches = 64
#width and height of the patches
patchsize = 128
#Train set is image 1 till 401
X_train,y_train = CreateSet(range(401),N_patches,patchsize)
#validation set is image 402 till 535
X_valid,y_valid = CreateSet(range(401,535),N_patches,patchsize)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# Done
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# Done

# %%
#Create the arrays for the Test set which are the image 601 till 669
test_set_indices = range(535,669)

Test_set_X = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
Test_set_y = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
for i,n in enumerate(test_set_indices):
    img = Image.open('bandLimited/input_%03d.png' % (n+1))
    in_img_input = tf.keras.preprocessing.image.img_to_array(img)
    in_img_input = skimage.transform.resize(in_img_input , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
    Test_set_X[i] =in_img_input / 255.0

    img = Image.open('groundTruth/target_%03d.png' % (n+1))
    in_img_output = tf.keras.preprocessing.image.img_to_array(img)
    in_img_output = skimage.transform.resize(in_img_output , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
    Test_set_y[i] =in_img_output / 255.0

# %%
def Sobel(x):
    dims = tf.shape(x)
    #return tf.squeeze( tf.image.sobel_edges(x))
    return tf.reshape(sobel(x),[dims[0],dims[1],dims[2],8])

def Sobel_shape(input_shape):
    dims = [input_shape[0],input_shape[1] ,input_shape[2],8]
    output_shape = tuple(dims)
    return output_shape

def RED_Net(img_tensor , n_filters = 64):
    """
    Creates the RED_net model
    returns: RED_net, the RED_net model
    """
# #     #block1 (connection 1-->2)
    shortcut1 = img_tensor
    
    #layer 1: edge detection layer which uses four kernel filters-
    x = tf.keras.layers.Lambda(Sobel, output_shape =  Sobel_shape, name='sobel-edge')(img_tensor)    #block1 (connection 1-->2)
    
    x = tf.keras.layers.concatenate([x, shortcut1])
    
#     #block 2(connection 2-->9)
    shortcut2 = x
#     #layer 2
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (5 , 5), padding = 'same')(x)
    
    #block 3(connection 3-->8)
    shortcut3 = x
    #layer 3
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=2, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
#     #block 4 (connection 4-->7)
    shortcut4 = x
    #layer 4
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
    #layer 5
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=4, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Dropout(0.05)(x)
    
    #layer 6
    x = tf.keras.layers.Conv2D(filters = n_filters , kernel_size = (3 , 3) , dilation_rate=3, padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
#     #block 4 (connection 4-->7)
    x = tf.keras.layers.concatenate([x, shortcut4])

    #layer 7
    x = tf.keras.layers.Conv2D(filters = n_filters ,kernel_size = (3 , 3),dilation_rate=2,padding = 'same')(x) 
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    
    #block 3(connection 3-->8)    
    x = tf.keras.layers.concatenate([x, shortcut3])

    #layer 8
    x = tf.keras.layers.Conv2D(1 , (3 , 3), padding = 'same')(x)
    #block 2(connection 2-->9)
    x = tf.keras.layers.concatenate([x, shortcut2])

    #layer 9 
    output = tf.keras.layers.Conv2D(1 , (3 , 3) , padding = 'same')(x)

    RED_net = tf.keras.Model(inputs = [img_tensor] , outputs = [output])

    return RED_net

# %%
def CustomMSE(y_predict,y_true):
    factor = 1
    mse = factor*K.mean(K.square(y_predict-y_true))
    return mse

# %%
#define and compile the model
img_tensor = tf.keras.layers.Input((None , None , 2) , name = 'img_tensor')
model = RED_Net(img_tensor,64)
model.compile(optimizer = tf.keras.optimizers.Adam(lr=0.0001, beta_1=0.5, beta_2=0.999, epsilon=1e-08, decay=0.0),
            loss=CustomMSE,
            metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model_path = 'model_RED_net_DoubleInput_ultrasound.h5'
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.0001, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(model_path, verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_tensor (InputLayer)         [(None, None, None,  0
# __________________________________________________________________________________________________
# sobel-edge (Lambda)             (None, None, None, 8 0           img_tensor[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 1 0           sobel-edge[0][0]
#                                                                  img_tensor[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 6 16064       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 6 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None, 6 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None, 6 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 6 36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 1 0           activation_3[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 6 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 1 0           activation_4[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 1 1153        concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           conv2d_6[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 100         concatenate_3[0][0]
# ==================================================================================================
# Total params: 240,101
# Trainable params: 239,461
# Non-trainable params: 640
# __________________________________________________________________________________________________

# %%
#train the model
results = model.fit(X_train,y_train,epochs=100, callbacks=callbacks,batch_size = 16,
                    validation_data=(X_valid,y_valid),shuffle=False)
# Out:
# Epoch 1/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1017
# Epoch 00001: val_loss improved from inf to 0.00902, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0103 - root_mean_squared_error: 0.1017 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950 - lr: 1.0000e-04
# Epoch 2/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0085 - root_mean_squared_error: 0.0922
# Epoch 00002: val_loss did not improve from 0.00902
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950 - lr: 1.0000e-04
# Epoch 3/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0084 - root_mean_squared_error: 0.0915
# Epoch 00003: val_loss improved from 0.00902 to 0.00900, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 151s 94ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949 - lr: 1.0000e-04
# Epoch 4/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0912
# Epoch 00004: val_loss improved from 0.00900 to 0.00900, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0949 - lr: 1.0000e-04
# Epoch 5/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0911
# Epoch 00005: val_loss improved from 0.00900 to 0.00899, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0948 - lr: 1.0000e-04
# Epoch 6/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0910
# Epoch 00006: val_loss improved from 0.00899 to 0.00895, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0946 - lr: 1.0000e-04
# Epoch 7/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0909
# Epoch 00007: val_loss improved from 0.00895 to 0.00893, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945 - lr: 1.0000e-04
# Epoch 8/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0909
# Epoch 00008: val_loss improved from 0.00893 to 0.00890, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943 - lr: 1.0000e-04
# Epoch 9/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0083 - root_mean_squared_error: 0.0908
# Epoch 00009: val_loss improved from 0.00890 to 0.00888, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0083 - root_mean_squared_error: 0.0908 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942 - lr: 1.0000e-04
# Epoch 10/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0908
# Epoch 00010: val_loss improved from 0.00888 to 0.00887, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942 - lr: 1.0000e-04
# Epoch 11/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0908
# Epoch 00011: val_loss improved from 0.00887 to 0.00886, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941 - lr: 1.0000e-04
# Epoch 12/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0908
# Epoch 00012: val_loss did not improve from 0.00886
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942 - lr: 1.0000e-04
# Epoch 13/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00013: val_loss improved from 0.00886 to 0.00886, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941 - lr: 1.0000e-04
# Epoch 14/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00014: val_loss improved from 0.00886 to 0.00884, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 148s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940 - lr: 1.0000e-04
# Epoch 15/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00015: val_loss improved from 0.00884 to 0.00883, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940 - lr: 1.0000e-04
# Epoch 16/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00016: val_loss improved from 0.00883 to 0.00881, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939 - lr: 1.0000e-04
# Epoch 17/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00017: val_loss improved from 0.00881 to 0.00881, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939 - lr: 1.0000e-04
# Epoch 18/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0907
# Epoch 00018: val_loss improved from 0.00881 to 0.00880, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938 - lr: 1.0000e-04
# Epoch 19/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00019: val_loss improved from 0.00880 to 0.00877, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937 - lr: 1.0000e-04
# Epoch 20/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00020: val_loss improved from 0.00877 to 0.00876, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936 - lr: 1.0000e-04
# Epoch 21/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00021: val_loss improved from 0.00876 to 0.00875, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936 - lr: 1.0000e-04
# Epoch 22/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00022: val_loss improved from 0.00875 to 0.00874, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 23/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00023: val_loss improved from 0.00874 to 0.00873, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934 - lr: 1.0000e-04
# Epoch 24/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00024: val_loss improved from 0.00873 to 0.00872, saving model to model_RED_net_DoubleInput_ultrasound.h5
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934 - lr: 1.0000e-04
# Epoch 25/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0906
# Epoch 00025: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 26/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00026: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 27/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00027: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 28/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00028: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 29/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00029: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0935 - lr: 1.0000e-04
# Epoch 30/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00030: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 150s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936 - lr: 1.0000e-04
# Epoch 31/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00031: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937 - lr: 1.0000e-04
# Epoch 32/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0905
# Epoch 00032: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0905 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0937 - lr: 1.0000e-04
# Epoch 33/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0904
# Epoch 00033: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938 - lr: 1.0000e-04
# Epoch 34/100
# 1604/1604 [==============================] - ETA: 0s - loss: 0.0082 - root_mean_squared_error: 0.0904
# Epoch 00034: val_loss did not improve from 0.00872
# 1604/1604 [==============================] - 149s 93ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938 - lr: 1.0000e-04
# Epoch 00034: early stopping

# %%
#load the model
model.load_weights(model_path)

# %%
#visualise the accuracy and losses of the model
# list all data in history
print(results.history.keys())
# summarize history for accuracy
plt.plot(results.history['root_mean_squared_error'])
plt.plot(results.history['val_root_mean_squared_error'])
plt.title('model root_mean_squared_error')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error', 'lr'])

# %%
def CreateTestSet(test_set_indices,input_dir_test,output_dir_test):
    """
    Function that reads in the test set images as arrays and scales them between 0 and 1
    parameters:test_set_indices: The indices of the the images in the test set
                 input_dir_test: The directory where the input png images are stored
                output_dir_test: The directory where the output png images are stored
    returns: Test_set_X: an array of input images
             Test_set_y: an array of output images
    """
    Test_set_X = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
    Test_set_y = np.zeros((len(test_set_indices), 801, 401, 1), dtype=np.float32)
    for i,n in enumerate(test_set_indices):
        img = Image.open(input_dir_test+'/input_%03d.png' % (n+1))
        in_img_input = tf.keras.preprocessing.image.img_to_array(img)
        in_img_input = skimage.transform.resize(in_img_input , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
        Test_set_X[i] =in_img_input / 255.0

        img = Image.open(output_dir_test+'/target_%03d.png' % (n+1))
        in_img_output = tf.keras.preprocessing.image.img_to_array(img)
        in_img_output = skimage.transform.resize(in_img_output , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
        Test_set_y[i] =in_img_output / 255.0    
    print('Done')
    return Test_set_X, Test_set_y
#Run for all datasets
for dataset in ['','CIRS_','carotid_']:
    if dataset == '':
        test_set_indices = range(535,669)
        input_dir_test = 'bandLimited'
        output_dir_test = 'groundTruth'
    if dataset == 'CIRS_':
        test_set_indices = range(11)
        input_dir_test = 'CIRSBandLimited'
        output_dir_test = 'CIRSGroundTruth'
    if dataset =='carotid_':
        test_set_indices = range(70)
        input_dir_test = 'carotidBandLimited'
        output_dir_test = 'carotidGroundTruth'
    #Create the input and output array for the test set
    Test_set_X, Test_set_y = CreateTestSet(test_set_indices,input_dir_test,output_dir_test)
    #load in the npy files for M1 and M2
    val_set_model1 = np.load('Model_output_test_'+dataset+'model1_ultrasound.npy')
    val_set_model2 = np.load('Model_output_test_'+dataset+'model2_ultrasound.npy')
    MODEL1 = np.zeros([len(val_set_model1),801,401,1])
    MODEL2 = np.zeros([len(val_set_model1),801,401,1])
    for i in range(len(val_set_model1)):
        img1 = skimage.transform.resize(val_set_model1[i] , (801 , 401 , 1) , mode = 'constant' , preserve_range = True)
        img2 = skimage.transform.resize(val_set_model2[i] , (801, 401 , 1) , mode = 'constant' , preserve_range = True)
        MODEL1[i] = img1
        MODEL2[i] = img2
    val_set_model1and2 = np.concatenate((MODEL1,MODEL2),axis=-1)
    prediction_images = np.zeros_like(val_set_model1)
    #Create an array of model generated images using M1 and M2 npy files as input
    for i in range(len(val_set_model1)):
        predicted_array = model.predict(np.expand_dims(val_set_model1and2[i],0))
        prediction_IMAGE = predicted_array.squeeze()
        prediction_images[i] = prediction_IMAGE
    #save the array as a npy file
    np.save('Model_output_test_'+dataset+'model4_ultrasound.npy',prediction_images)
# Out:
# Done
# Done
# Done
